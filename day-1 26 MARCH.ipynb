# %% [markdown]
# # one
# ## two
# ### three
# #### four
# ##### five
#
# - point1
# - point2
# - point3
# - point4
# - point5
#   * point1
#   * point2
#   * point3
#       * point4
#       * point5
#
#   i am in **Bold** style <br>
#   i am in *italic* style <br>
#   i am in ***bold+italic*** style
#
#    hi guys,welcome to ```hello```
#
#  - inserting tables
#
# col1 | col2 | col3
# -|-|-
# r1 | r2 | r3
# r4 | r5| r6
#
#   - inserting link
#
# [Python official website](http://www.vignaniit.edu.in/)
#
#   - inserting image
#
# ![](data:image/jpeg;base64,...)
#
# ![](mycar.jpg)
#
# ![](screenshot.jpg)
#
# <img src=screenshot.jpg height="75%" width="50%">
